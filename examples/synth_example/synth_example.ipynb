# %% [markdown]
# # Simple synthetic example

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import swspy
import matplotlib 
# %matplotlib notebook

# %%
LQT_st = swspy.splitting.forward_model.create_src_time_func(10., 1000)
LQT_st.plot()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
swspy.__path__
# Out:
# ['/Users/eart0504/Documents/python/github_repositories/swspy/swspy']
